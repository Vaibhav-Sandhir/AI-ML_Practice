# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# y = mx + b
x = np.random.normal(0, 1, 40)  # Gradient Descent works best with normalized data
y =  5* x + 10

# %%
def loss_function(m, b, x, y):
    total_error = 0.0
    n = x.shape[0]
    for i in range(n):
        total_error += (y[i] - (m * x[i] + b)) ** 2
    total_error = total_error / n
    return total_error

# %%
def gradient_descent(m_now, b_now, x, y, learning_rate):
    dldm = 0.0
    dldb = 0.0
    n = x.shape[0]
    
    for i in range(n):
        dldm += -(2/n) * x[i] * (y[i] - (m_now * x[i] + b_now))
        dldb += -(2/n) * (y[i] - (m_now * x[i] + b_now))
     
    m = m_now - dldm * learning_rate
    b = b_now - dldb * learning_rate
    
    return m, b

# %%
m = 0.0
b = 0.0
learning_rate = 0.01
epoch = 1000

for i in range(epoch):
    m, b = gradient_descent(m, b, x, y, learning_rate)
    if i % 100 == 0:
        print(f'Epoch {i}, loss is {loss_function(m, b, x, y)}, m = {m}, b = {b}')
# Out:
# Epoch 0, loss is 150.46699813598616, m = 0.18044102893288705, b = 0.2273310477817332
# Epoch 100, loss is 1.3200676467759531, m = 5.142755603672783, b = 8.82258221672546
# Epoch 200, loss is 0.03489661647639665, m = 5.084634513242678, b = 9.814319625970768
# Epoch 300, loss is 0.0012069754526748185, m = 5.019137801962629, b = 9.966954657716224
# Epoch 400, loss is 4.289769880031331e-05, m = 5.003785840569258, b = 9.99387206460151
# Epoch 500, loss is 1.528212500146278e-06, m = 5.00072413237011, b = 9.998849281728011
# Epoch 600, loss is 5.445266382295291e-08, m = 5.000137211465588, b = 9.999783114636248
# Epoch 700, loss is 1.9402680525682723e-09, m = 5.00002592926357, b = 9.999959077708802
# Epoch 800, loss is 6.913611064466574e-11, m = 5.000004896103037, b = 9.999992276292307
# Epoch 900, loss is 2.4634752688045364e-12, m = 5.0000009242989405, b = 9.999998542088116

# %%
plt.figure("Results", (18, 12))
plt.subplot(2,2,1)
plt.plot(x, y, color = 'red', label = 'Orignal')
plt.title('Orignal')

plt.subplot(2,2,2)
plt.title('Predicted')
plt.plot(x, m*x + b, color = 'blue', label = 'Predicted')
plt.show()
